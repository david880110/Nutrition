# %%
# Ddd dependencies
import pandas as pd

from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

from sqlalchemy import Column, Integer, String, Float, Date

# %%
# Load csv files
raw_data = 'raw_data/nutrition_data.csv'

# %%
# Read Raw Data File and store into Pandas Data Frames
raw_data_df = pd.read_csv(raw_data)

# %%
raw_data_df.head()
# Out:
#                     dataset  category   vendor article_no  \
# 0  Master List SRS Transfer  Material  Grocery    1118633
# 1  Master List SRS Transfer  Material  Grocery    1131522
# 2  Master List SRS Transfer  Material  Grocery    1154001
# 3  Master List SRS Transfer  Material  Grocery    1159835
# 4  Master List SRS Transfer  Material  Grocery    1299105
#
#    article_description_en article_description_ch pack_size  \
# 0       TABASCO HOT SAUCE                    NaN    24/2OZ
# 1      SPAM LUNCHEON MEAT               世棒午餐肉-原味   24/12OZ
# 2  TROPICAL PANCAKE SYRUP                 （胡桃）糖漿       NaN
# 3  DOLE SEEDLESS RAISIN C                    NaN       NaN
# 4                   PECAN                 胡桃（半颗）       NaN
#
#                                               source serving_size  \
# 0                                         1231 Sushi            1
# 1  https://ndb.nal.usda.gov/ndb/foods/show/300771...            1
# ...

# %%
# Create the Schools_data class
class Nutrition_table(Base):
    __tablename__ = 'nutrition_table'
    article_no = Column(Integer, primary_key = True)
    dataset = Column(String(255))
    category = Column(String(255))
    vendor = Column(String(255))
    article_description_en = Column(String(255))
    article_description_ch = Column(String(255))
    pack_size = Column(String(255))
    source = Column(String(255))
    serving_size = Column(Float)
    total_calories_cal = Column(Float)
    calories_from_fat_fat_cal = Column(Float)
    total_fat_g = Column(Float)
    saturated_fat_g = Column(Float)
    trans_fat_g = Column(Float)
    cholesterol_mg = Column(Float)
    sodium_mg = Column(Float)
    total_carbohydrate_g = Column(Float)
    dietary_fiber_g = Column(Float)
    sugars_g = Column(Float)
    protein_g = Column(Float)

# %%
# Create the datbase and add the classes
engine = create_engine("sqlite:///nutrition_database.sqlite", echo = False)
conn = engine.connect()
session = Session(engine)

Base.metadata.create_all(conn)

# %%
# Send the station dataframe to the sqlite database
raw_data_df.to_sql('nutrition_table', engine, if_exists='replace')
